# %% [markdown]
# <a href="https://colab.research.google.com/github/saishanakar/numpy/blob/main/Untitled5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
data=pd.read_csv('CARS_1.csv')
print(data)
# Out:
#                         car_name  reviews_count fuel_type  \
# 0                Maruti Alto K10             51    Petrol
# 1                  Maruti Brezza             86    Petrol
# 2                  Mahindra Thar            242    Diesel
# 3                Mahindra XUV700            313    Diesel
# 4             Mahindra Scorpio-N            107    Diesel
# ..                           ...            ...       ...
# 198     Mercedes-Benz AMG A 45 S             35    Petrol
# 199  BMW 3 Series Gran Limousine              3    Petrol
# 200               MG Hector Plus              2    Diesel
# 201                   Audi RS Q8              9    Petrol
# 202         Maruti Alto 800 tour              4    Petrol
#
#      engine_displacement  no_cylinder  seating_capacity transmission_type  \
# 0                    998            3               5.0         Automatic
# 1                   1462            4               5.0         Automatic
# ...

# %%
data.head(6)
# Out:
#              car_name  reviews_count fuel_type  engine_displacement  \
# 0     Maruti Alto K10             51    Petrol                  998
# 1       Maruti Brezza             86    Petrol                 1462
# 2       Mahindra Thar            242    Diesel                 2184
# 3     Mahindra XUV700            313    Diesel                 2198
# 4  Mahindra Scorpio-N            107    Diesel                 2198
# 5     Toyota Fortuner             99    Diesel                 2755
#
#    no_cylinder  seating_capacity transmission_type  fuel_tank_capacity  \
# 0            3               5.0         Automatic                27.0
# 1            4               5.0         Automatic                48.0
# 2            4               4.0         Automatic                57.0
# 3            4               7.0         Automatic                60.0
# 4            4               7.0         Automatic                57.0
# ...

# %%
data.tail(1)
# Out:
#                  car_name  reviews_count fuel_type  engine_displacement  \
# 202  Maruti Alto 800 tour              4    Petrol                  796
#
#      no_cylinder  seating_capacity transmission_type  fuel_tank_capacity  \
# 202            3               5.0            Manual                35.0
#
#      body_type  rating  starting_price  ending_price  max_torque_nm  \
# 202  Hatchback     4.5          391000        397000           69.0
#
#      max_torque_rpm  max_power_bhp  max_power_rp
# 202            3500          47.33          6000

# %%
data['fuel_tank_capacity']
# Out:
# 0      27.0
# 1      48.0
# 2      57.0
# 3      60.0
# 4      57.0
#        ...
# 198     0.0
# 199    59.0
# 200    60.0
# 201    85.0
# 202    35.0
# Name: fuel_tank_capacity, Length: 203, dtype: float64

# %%
print(data.loc[2:500, ['car_name', 'reviews_count']])
# Out:
#                         car_name  reviews_count
# 2                  Mahindra Thar            242
# 3                Mahindra XUV700            313
# 4             Mahindra Scorpio-N            107
# 5                Toyota Fortuner             99
# 6                  Hyundai Creta            731
# ..                           ...            ...
# 198     Mercedes-Benz AMG A 45 S             35
# 199  BMW 3 Series Gran Limousine              3
# 200               MG Hector Plus              2
# 201                   Audi RS Q8              9
# 202         Maruti Alto 800 tour              4
#
# [201 rows x 2 columns]

# %%
d=pd.read_csv('CARS_1.csv')
print(d.to_string())
# Out:
#                             car_name  reviews_count fuel_type  engine_displacement  no_cylinder  seating_capacity transmission_type  fuel_tank_capacity     body_type  rating  starting_price  ending_price  max_torque_nm  max_torque_rpm  max_power_bhp  max_power_rp
# 0                    Maruti Alto K10             51    Petrol                  998            3               5.0         Automatic                27.0     Hatchback     4.5          399000        583000          89.00            3500          65.71          5500
# 1                      Maruti Brezza             86    Petrol                 1462            4               5.0         Automatic                48.0           SUV     4.5          799000       1396000         136.80            4400         101.65          6000
# ...

# %%
d0=d.loc[:5,['car_name','reviews_count']]

# %%
d1=d.loc[:5,['car_name','no_cylinder']]

# %%
pd.merge(d1,d0,on='car_name')
# Out:
#              car_name  no_cylinder  reviews_count
# 0     Maruti Alto K10            3             51
# 1       Maruti Brezza            4             86
# 2       Mahindra Thar            4            242
# 3     Mahindra XUV700            4            313
# 4  Mahindra Scorpio-N            4            107
# 5     Toyota Fortuner            4             99

# %%
g=data.groupby('engine_displacement')

# %%
g.get_group(0)
# Out:
#                   car_name  reviews_count fuel_type  engine_displacement  \
# 36   Hyundai Kona Electric             40  Electric                    0
# 75                 Kia EV6             15  Electric                    0
# 95                MG ZS EV             14  Electric                    0
# 98                  BMW i4              8  Electric                    0
# 113                 BYD E6              6  Electric                    0
# 117         Mini Cooper SE              3  Electric                    0
# 118            Audi e-tron              7  Electric                    0
# 123         Porsche Taycan              8  Electric                    0
# 127                 BMW iX              3  Electric                    0
# 139      Mercedes-Benz EQS              2  Electric                    0
# 147      Mahindra E Verito             14  Electric                    0
# 158        Strom Motors R3              2  Electric                    0
# ...

# %%
pd.concat([d0,d1])
# Out:
#              car_name  reviews_count  no_cylinder
# 0     Maruti Alto K10           51.0          NaN
# 1       Maruti Brezza           86.0          NaN
# 2       Mahindra Thar          242.0          NaN
# 3     Mahindra XUV700          313.0          NaN
# 4  Mahindra Scorpio-N          107.0          NaN
# 5     Toyota Fortuner           99.0          NaN
# 0     Maruti Alto K10            NaN          3.0
# 1       Maruti Brezza            NaN          4.0
# 2       Mahindra Thar            NaN          4.0
# 3     Mahindra XUV700            NaN          4.0
# 4  Mahindra Scorpio-N            NaN          4.0
# 5     Toyota Fortuner            NaN          4.0

# %%
df2=d['rating']

# %%
df3=d['fuel_tank_capacity']

# %%
  pd.concat([df3,df2])
# Out:
# 0      27.0
# 1      48.0
# 2      57.0
# 3      60.0
# 4      57.0
#        ...
# 198     4.5
# 199     4.5
# 200     4.5
# 201     3.5
# 202     4.5
# Length: 406, dtype: float64

# %%
df3=d['transmission_type']

# %%
pd.concat([df3,df2,df3],axis=1)
# Out:
#     transmission_type  rating transmission_type
# 0           Automatic     4.5         Automatic
# 1           Automatic     4.5         Automatic
# 2           Automatic     4.5         Automatic
# 3           Automatic     4.5         Automatic
# 4           Automatic     4.5         Automatic
# ..                ...     ...               ...
# 198         Automatic     4.5         Automatic
# 199         Automatic     4.5         Automatic
# 200            Manual     4.5            Manual
# 201         Automatic     3.5         Automatic
# 202            Manual     4.5            Manual
#
# [203 rows x 3 columns]

# %%
d.describe()
# Out:
#        reviews_count  engine_displacement  no_cylinder  seating_capacity  \
# count     203.000000           203.000000   203.000000        202.000000
# mean      118.684729          2305.921182     4.709360          5.014851
# std       314.331318          1493.837786     2.538664          1.161050
# min         1.000000             0.000000     0.000000          2.000000
# 25%         5.000000          1339.500000     4.000000          5.000000
# 50%        14.000000          1991.000000     4.000000          5.000000
# 75%        83.000000          2996.000000     6.000000          5.000000
# max      2392.000000          6750.000000    12.000000          8.000000
#
#        fuel_tank_capacity      rating  starting_price  ending_price  \
# count          203.000000  203.000000    2.030000e+02  2.030000e+02
# mean            46.143842    4.433498    9.443640e+06  1.112005e+07
# std             28.904207    0.280136    1.357035e+07  1.551746e+07
# ...

# %%
g.describe()
# Out:
#                     reviews_count                                             \
#                             count      mean         std   min     25%    50%
# engine_displacement
# 0                            16.0    8.1875    9.738027   1.0    2.00    6.0
# 216                           1.0   43.0000         NaN  43.0   43.00   43.0
# 796                           2.0  220.5000  306.177236   4.0  112.25  220.5
# 998                           6.0  195.0000  160.632500  36.0   60.50  175.0
# 999                           6.0  331.0000  276.162271  67.0  127.50  253.0
# ...                           ...       ...         ...   ...     ...    ...
# 6496                          1.0    3.0000         NaN   3.0    3.00    3.0
# 6498                          1.0   52.0000         NaN  52.0   52.00   52.0
# 6592                          1.0    6.0000         NaN   6.0    6.00    6.0
# 6598                          1.0    2.0000         NaN   2.0    2.00    2.0
# ...
